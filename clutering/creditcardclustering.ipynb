# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r'C:\Users\RISHYENDRA KUMAR\mloperation\data\creditcardclust.csv')

# %%
df.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(df[col].value_counts())
    print('---------')
# Out:
# CUST_ID
# C10001    1
# C16135    1
# C16129    1
# C16130    1
# C16131    1
#          ..
# C13065    1
# C13064    1
# C13063    1
# C13062    1
# C19190    1
# Name: count, Length: 8950, dtype: int64
# ---------

# %%
df=df.drop(['CUST_ID'],axis=1)

# %%
n_df = df.select_dtypes(include=['float64','int64'])

# %%
n_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
n_df.shape
# Out:
# (8950, 17)

# %%
n_df.isnull().mean()*100
# Out:
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import missingno as msno
# from statsmodels.imputation import mice
# # Visualize missing data
# msno.matrix(df['MINIMUM_PAYMENTS'])
# msno.heatmap(df['MINIMUM_PAYMENTS'])

## Perform Little's MCAR test
# mcar_test_results = mice.MCAR(df['MINIMUM_PAYMENTS'])
# print(mcar_test_results)

# %%
n_df=n_df.dropna()

# %%
for col in n_df.columns:
    print(sns.displot(col))

# %%
sns.boxplot(n_df)
# Out:
# <Axes: >

# %%
# def wisker(col):
#   q1=df[col].quantile(0.25)
#   q3=df[col].quantile(0.75)
#   iqr=q3-q1
#   lower=q1-(1.5*iqr)
#   upper=q3+(1.5*iqr)
#   return lower,upper

# %%
# for col in n_df.select_dtypes(include=['number']).columns:
#   lower,upper=wisker(col)
#   n_df[col]=np.where(n_df[col]<lower,lower,n_df[col])
#   n_df[col]=np.where(n_df[col]>upper,upper,n_df[col])

# %%
# for col in n_df.columns:
#     sns.boxplot(n_df[col])
#     plt.show()

# %%
#scaling num data
from sklearn.preprocessing import StandardScaler,MinMaxScaler
ss=StandardScaler()
mm=MinMaxScaler()
s_df=ss.fit_transform(n_df)
#s_df=mm.fit_transform(n_df)

# %%
s_df = pd.DataFrame(s_df, columns=n_df.columns)

# %%
sns.boxplot(s_df)
# Out:
# <Axes: >

# %%
cat_df = df.select_dtypes(include=['object'])

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
# Use the Elbow Method to find the optimal number of clusters
wcss = []  # Within-cluster sum of squares

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(s_df)
    wcss.append(kmeans.inertia_)

# Plot the Elbow graph
sns.set()
plt.figure(figsize=(6, 6))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Calculate the silhouette score
silhouette_avg = silhouette_score(s_df, clusters)
print(f'Silhouette Score: {silhouette_avg:.4f}')
# Out:
# Silhouette Score: 0.2239

# %%
# Apply K-means with the optimal number of clusters
optimal_k = 3  # Replace with the optimal number of clusters from the Elbow graph
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
clusters = kmeans.fit_predict(s_df)

# Add the cluster labels to the original dataframe
df['Cluster'] = clusters

# Reduce the dimensions for visualization using PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(s_df)

# Get the centroids
centroids = kmeans.cluster_centers_
pca_centroids = pca.transform(scaler.inverse_transform(centroids))  # Transform centroids back to original scale for visualization

# Plot the clusters and centroids
plt.figure(figsize=(12, 8))
scatter = plt.scatter(pca_data[:, 0], pca_data[:, 1], c=clusters, cmap='viridis', marker='o', edgecolor='k', alpha=0.7)
plt.scatter(pca_centroids[:, 0], pca_centroids[:, 1], c='red', s=300, marker='X', label='centroids')

# Add labels and legend
plt.title('Clusters and Centroids')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.colorbar(scatter, label='Cluster')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Apply K-means with the optimal number of clusters
#       2 optimal_k = 3  # Replace with the optimal number of clusters from the Elbow graph
# ----> 3 kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
#       4 clusters = kmeans.fit_predict(s_df)
#       6 # Add the cluster labels to the original dataframe
#
# NameError: name 'KMeans' is not defined

# %%
# Apply K-means with the optimal number of clusters
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=300, n_init=10, random_state=0)
clusters = kmeans.fit_predict(s_df)

# Add the cluster labels to the original dataframe
s_df['Cluster'] = clusters

# Display the first few rows with the cluster labels
print(n_df.head())
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
# Reduce the dimensions for visualization using PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(s_df)

# Plot the clusters
plt.figure(figsize=(10, 5))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=clusters, cmap='viridis',label='centroids')
plt.title('Clusters Visualization')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()
